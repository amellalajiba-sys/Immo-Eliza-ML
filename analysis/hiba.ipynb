# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\asus\\OneDrive\\Bureau\\becode_projects\\Immo-Eliza-ML\\data\\cleaned_scraped_properties.csv")

print(df["province"].unique())
print(df["type_property"].unique())
print(df["subtype_property"].unique())
print(df["state_of_property"].unique())
print(df["heating_type"].unique())
print(df["sun_exposure"].unique())
print(df["epc_score"].unique())
print(df["flooding_area_type"].unique())
# Out:
# <StringArray>
# [      'brussels', 'vlaams_brabant',        'antwerp',  'east_flanders',
#   'west_flanders', 'brabant_wallon',        'limburg',        'hainaut',
#           'namur',          'liege',     'luxembourg']
# Length: 11, dtype: str
# <StringArray>
# ['house', 'apartment']
# Length: 2, dtype: str
# <StringArray>
# [     'residence',         'duplex',      'apartment',         'studio',
#  'mixed_building',   'ground_floor',      'penthouse',          'villa',
#            'loft',        'triplex',   'master_house',       'bungalow',
#          'chalet',        'cottage',        'mansion']
# Length: 15, dtype: str
# <StringArray>
# [   'to_be_renovated',          'excellent',             'normal',
#     'fully_renovated',        'to_renovate',      'not_specified',
#                 'new',        'to_demolish',         'to_restore',
#  'under_construction']
# Length: 10, dtype: str
# <StringArray>
# [     'fuel_oil',           'gas',   'electricity', 'not_specified',
# ...
